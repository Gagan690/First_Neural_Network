# %% [markdown]
# # EMNIST

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torchvision import transforms , datasets
from torch.utils.data import DataLoader

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,),(0.5,))
])

# %%
train_dataset = datasets.QMNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.QMNIST(root='./data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
# Out:
# 100%|██████████| 9.70M/9.70M [00:00<00:00, 170MB/s]
# 100%|██████████| 463k/463k [00:00<00:00, 15.2MB/s]
# 100%|██████████| 9.74M/9.74M [00:00<00:00, 135MB/s]
# 100%|██████████| 527k/527k [00:00<00:00, 15.8MB/s]

# %%
class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.conv1 = nn.Conv2d(1,6, kernel_size=5, stride=1, padding=1)
    self.conv2 = nn.Conv2d(6, 16, kernel_size=5, stride=1)
    self.fc1 = nn.Linear(16*4*4, 120) # Corrected input size
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84,10)

  def forward(self, x):
    x = torch.relu(self.conv1(x))
    x = torch.max_pool2d(x , kernel_size=2, stride=2)
    x = torch.relu(self.conv2(x))
    x = torch.max_pool2d(x , kernel_size=2, stride=2)
    x = x.view(-1, 16 * 4 * 4) # Corrected flattening size
    x = torch.relu(self.fc1(x))
    x = torch.relu(self.fc2(x))
    x = self.fc3(x)
    return x

# %%
model = Net()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
def train(model, train_loader ,criteriion, optimizer, epoch):
  model.train()
  for batch_idx , (data, target) in enumerate(train_loader):
    optimizer.zero_grad()
    outputs = model(data)
    loss = criteriion(outputs, target)
    loss.backward()
    optimizer.step()

    if batch_idx % 100 == 0:
      print(f"Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item():.6f}")

# %%
def test(model, test_loader, criterion):
  model.eval()
  test_loss = 0
  correct = 0
  with torch.no_grad():
    for data, target in test_loader:
      outputs = model(data)
      test_loss += criterion(outputs, target).item()

      pred = outputs.argmax(dim=1, keepdim=True)
      correct += pred.eq(target.view_as(pred)).sum().item()

  test_loss /= len(test_loader.dataset)
  print(f"\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} ({100. * correct / len(test_loader.dataset):.0f}%)\n")

# %%
num_epoch = 25
for epoch in range(1, num_epoch+1):
  train(model, train_loader, criterion, optimizer, epoch)
  test(model, test_loader, criterion)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.312301
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 1.520458
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.243973
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.255340
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.225784
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.140613
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.056044
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.091558
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.051244
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.122212
#
# Test set: Average loss: 0.0015, Accuracy: 58166/60000 (97%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.187735
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.062144
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.053865
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.040629
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.048662
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.126438
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.071371
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.066574
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.046661
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.005427
#
# Test set: Average loss: 0.0011, Accuracy: 58644/60000 (98%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.082844
# Train Epoch: 3 [6400/60000 (11%)]	Loss: 0.001358
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.091401
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 0.008402
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.033897
# Train Epoch: 3 [32000/60000 (53%)]	Loss: 0.007828
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.008458
# Train Epoch: 3 [44800/60000 (75%)]	Loss: 0.021132
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.007084
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 0.050704
#
# Test set: Average loss: 0.0008, Accuracy: 59019/60000 (98%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.027162
# Train Epoch: 4 [6400/60000 (11%)]	Loss: 0.039907
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.132081
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 0.008889
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.088204
# Train Epoch: 4 [32000/60000 (53%)]	Loss: 0.017331
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.018325
# Train Epoch: 4 [44800/60000 (75%)]	Loss: 0.052651
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.016758
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 0.014132
#
# Test set: Average loss: 0.0009, Accuracy: 58982/60000 (98%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.003692
# Train Epoch: 5 [6400/60000 (11%)]	Loss: 0.009995
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.008834
# Train Epoch: 5 [19200/60000 (32%)]	Loss: 0.012412
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.007587
# Train Epoch: 5 [32000/60000 (53%)]	Loss: 0.010292
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.053240
# Train Epoch: 5 [44800/60000 (75%)]	Loss: 0.007434
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.152362
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 0.016850
#
# Test set: Average loss: 0.0007, Accuracy: 59226/60000 (99%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.055570
# Train Epoch: 6 [6400/60000 (11%)]	Loss: 0.030801
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.000534
# Train Epoch: 6 [19200/60000 (32%)]	Loss: 0.008684
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.034609
# Train Epoch: 6 [32000/60000 (53%)]	Loss: 0.121285
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.002657
# Train Epoch: 6 [44800/60000 (75%)]	Loss: 0.010097
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.053758
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 0.006516
#
# Test set: Average loss: 0.0007, Accuracy: 59217/60000 (99%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.007491
# Train Epoch: 7 [6400/60000 (11%)]	Loss: 0.008075
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.003215
# Train Epoch: 7 [19200/60000 (32%)]	Loss: 0.009071
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.034552
# Train Epoch: 7 [32000/60000 (53%)]	Loss: 0.000910
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.012531
# Train Epoch: 7 [44800/60000 (75%)]	Loss: 0.006676
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.007543
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 0.008507
#
# Test set: Average loss: 0.0008, Accuracy: 59056/60000 (98%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.049884
# Train Epoch: 8 [6400/60000 (11%)]	Loss: 0.011912
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.050104
# Train Epoch: 8 [19200/60000 (32%)]	Loss: 0.025438
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.000525
# Train Epoch: 8 [32000/60000 (53%)]	Loss: 0.000942
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.000778
# Train Epoch: 8 [44800/60000 (75%)]	Loss: 0.001133
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.027525
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 0.017162
#
# Test set: Average loss: 0.0007, Accuracy: 59236/60000 (99%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.041690
# Train Epoch: 9 [6400/60000 (11%)]	Loss: 0.002816
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.010684
# Train Epoch: 9 [19200/60000 (32%)]	Loss: 0.001642
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.007535
# Train Epoch: 9 [32000/60000 (53%)]	Loss: 0.001892
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.003334
# Train Epoch: 9 [44800/60000 (75%)]	Loss: 0.021702
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.052902
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 0.041089
#
# Test set: Average loss: 0.0006, Accuracy: 59289/60000 (99%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.001212
# Train Epoch: 10 [6400/60000 (11%)]	Loss: 0.070765
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 0.012159
# Train Epoch: 10 [19200/60000 (32%)]	Loss: 0.075949
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.000352
# Train Epoch: 10 [32000/60000 (53%)]	Loss: 0.001373
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 0.018339
# Train Epoch: 10 [44800/60000 (75%)]	Loss: 0.002171
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.007997
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 0.039620
#
# Test set: Average loss: 0.0008, Accuracy: 59158/60000 (99%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 0.003663
# Train Epoch: 11 [6400/60000 (11%)]	Loss: 0.001700
# Train Epoch: 11 [12800/60000 (21%)]	Loss: 0.013964
# Train Epoch: 11 [19200/60000 (32%)]	Loss: 0.003568
# Train Epoch: 11 [25600/60000 (43%)]	Loss: 0.000718
# Train Epoch: 11 [32000/60000 (53%)]	Loss: 0.012675
# Train Epoch: 11 [38400/60000 (64%)]	Loss: 0.004706
# Train Epoch: 11 [44800/60000 (75%)]	Loss: 0.007485
# Train Epoch: 11 [51200/60000 (85%)]	Loss: 0.027877
# Train Epoch: 11 [57600/60000 (96%)]	Loss: 0.015950
#
# Test set: Average loss: 0.0007, Accuracy: 59304/60000 (99%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 0.003296
# Train Epoch: 12 [6400/60000 (11%)]	Loss: 0.001201
# Train Epoch: 12 [12800/60000 (21%)]	Loss: 0.003098
# Train Epoch: 12 [19200/60000 (32%)]	Loss: 0.018540
# Train Epoch: 12 [25600/60000 (43%)]	Loss: 0.002288
# Train Epoch: 12 [32000/60000 (53%)]	Loss: 0.000186
# Train Epoch: 12 [38400/60000 (64%)]	Loss: 0.001647
# Train Epoch: 12 [44800/60000 (75%)]	Loss: 0.053840
# Train Epoch: 12 [51200/60000 (85%)]	Loss: 0.001819
# Train Epoch: 12 [57600/60000 (96%)]	Loss: 0.001884
#
# Test set: Average loss: 0.0007, Accuracy: 59297/60000 (99%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 0.024453
# Train Epoch: 13 [6400/60000 (11%)]	Loss: 0.001438
# Train Epoch: 13 [12800/60000 (21%)]	Loss: 0.000306
# Train Epoch: 13 [19200/60000 (32%)]	Loss: 0.000423
# Train Epoch: 13 [25600/60000 (43%)]	Loss: 0.000338
# Train Epoch: 13 [32000/60000 (53%)]	Loss: 0.003278
# Train Epoch: 13 [38400/60000 (64%)]	Loss: 0.000164
# Train Epoch: 13 [44800/60000 (75%)]	Loss: 0.001418
# Train Epoch: 13 [51200/60000 (85%)]	Loss: 0.003626
# Train Epoch: 13 [57600/60000 (96%)]	Loss: 0.001527
#
# Test set: Average loss: 0.0007, Accuracy: 59337/60000 (99%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 0.000133
# Train Epoch: 14 [6400/60000 (11%)]	Loss: 0.004305
# Train Epoch: 14 [12800/60000 (21%)]	Loss: 0.006820
# Train Epoch: 14 [19200/60000 (32%)]	Loss: 0.002879
# Train Epoch: 14 [25600/60000 (43%)]	Loss: 0.001823
# Train Epoch: 14 [32000/60000 (53%)]	Loss: 0.008204
# Train Epoch: 14 [38400/60000 (64%)]	Loss: 0.000938
# Train Epoch: 14 [44800/60000 (75%)]	Loss: 0.000028
# Train Epoch: 14 [51200/60000 (85%)]	Loss: 0.005151
# Train Epoch: 14 [57600/60000 (96%)]	Loss: 0.005237
#
# Test set: Average loss: 0.0008, Accuracy: 59188/60000 (99%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 0.002611
# Train Epoch: 15 [6400/60000 (11%)]	Loss: 0.018725
# Train Epoch: 15 [12800/60000 (21%)]	Loss: 0.000129
# Train Epoch: 15 [19200/60000 (32%)]	Loss: 0.002840
# Train Epoch: 15 [25600/60000 (43%)]	Loss: 0.039752
# Train Epoch: 15 [32000/60000 (53%)]	Loss: 0.002212
# Train Epoch: 15 [38400/60000 (64%)]	Loss: 0.001033
# Train Epoch: 15 [44800/60000 (75%)]	Loss: 0.000274
# Train Epoch: 15 [51200/60000 (85%)]	Loss: 0.006223
# Train Epoch: 15 [57600/60000 (96%)]	Loss: 0.000232
#
# Test set: Average loss: 0.0008, Accuracy: 59271/60000 (99%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 0.002801
# Train Epoch: 16 [6400/60000 (11%)]	Loss: 0.000777
# Train Epoch: 16 [12800/60000 (21%)]	Loss: 0.001655
# Train Epoch: 16 [19200/60000 (32%)]	Loss: 0.000113
# Train Epoch: 16 [25600/60000 (43%)]	Loss: 0.002497
# Train Epoch: 16 [32000/60000 (53%)]	Loss: 0.000022
# Train Epoch: 16 [38400/60000 (64%)]	Loss: 0.016231
# Train Epoch: 16 [44800/60000 (75%)]	Loss: 0.001991
# Train Epoch: 16 [51200/60000 (85%)]	Loss: 0.000105
# Train Epoch: 16 [57600/60000 (96%)]	Loss: 0.003243
#
# Test set: Average loss: 0.0008, Accuracy: 59322/60000 (99%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 0.000435
# Train Epoch: 17 [6400/60000 (11%)]	Loss: 0.008302
# Train Epoch: 17 [12800/60000 (21%)]	Loss: 0.000047
# Train Epoch: 17 [19200/60000 (32%)]	Loss: 0.004244
# Train Epoch: 17 [25600/60000 (43%)]	Loss: 0.000059
# Train Epoch: 17 [32000/60000 (53%)]	Loss: 0.001098
# Train Epoch: 17 [38400/60000 (64%)]	Loss: 0.000559
# Train Epoch: 17 [44800/60000 (75%)]	Loss: 0.017306
# Train Epoch: 17 [51200/60000 (85%)]	Loss: 0.001663
# Train Epoch: 17 [57600/60000 (96%)]	Loss: 0.000294
#
# Test set: Average loss: 0.0009, Accuracy: 59163/60000 (99%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 0.000535
# Train Epoch: 18 [6400/60000 (11%)]	Loss: 0.002661
# Train Epoch: 18 [12800/60000 (21%)]	Loss: 0.000267
# Train Epoch: 18 [19200/60000 (32%)]	Loss: 0.001267
# Train Epoch: 18 [25600/60000 (43%)]	Loss: 0.009363
# Train Epoch: 18 [32000/60000 (53%)]	Loss: 0.000026
# Train Epoch: 18 [38400/60000 (64%)]	Loss: 0.001455
# Train Epoch: 18 [44800/60000 (75%)]	Loss: 0.000177
# Train Epoch: 18 [51200/60000 (85%)]	Loss: 0.002458
# Train Epoch: 18 [57600/60000 (96%)]	Loss: 0.000453
#
# Test set: Average loss: 0.0009, Accuracy: 59232/60000 (99%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 0.008518
# Train Epoch: 19 [6400/60000 (11%)]	Loss: 0.000031
# Train Epoch: 19 [12800/60000 (21%)]	Loss: 0.001651
# Train Epoch: 19 [19200/60000 (32%)]	Loss: 0.000351
# Train Epoch: 19 [25600/60000 (43%)]	Loss: 0.000098
# Train Epoch: 19 [32000/60000 (53%)]	Loss: 0.000179
# Train Epoch: 19 [38400/60000 (64%)]	Loss: 0.010724
# Train Epoch: 19 [44800/60000 (75%)]	Loss: 0.000181
# Train Epoch: 19 [51200/60000 (85%)]	Loss: 0.003373
# Train Epoch: 19 [57600/60000 (96%)]	Loss: 0.021045
#
# Test set: Average loss: 0.0008, Accuracy: 59216/60000 (99%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 0.000688
# Train Epoch: 20 [6400/60000 (11%)]	Loss: 0.024235
# Train Epoch: 20 [12800/60000 (21%)]	Loss: 0.018753
# Train Epoch: 20 [19200/60000 (32%)]	Loss: 0.001159
# Train Epoch: 20 [25600/60000 (43%)]	Loss: 0.000046
# Train Epoch: 20 [32000/60000 (53%)]	Loss: 0.000968
# Train Epoch: 20 [38400/60000 (64%)]	Loss: 0.000122
# Train Epoch: 20 [44800/60000 (75%)]	Loss: 0.007053
# Train Epoch: 20 [51200/60000 (85%)]	Loss: 0.000549
# Train Epoch: 20 [57600/60000 (96%)]	Loss: 0.007116
#
# Test set: Average loss: 0.0008, Accuracy: 59344/60000 (99%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 0.000093
# Train Epoch: 21 [6400/60000 (11%)]	Loss: 0.001220
# Train Epoch: 21 [12800/60000 (21%)]	Loss: 0.002516
# Train Epoch: 21 [19200/60000 (32%)]	Loss: 0.001180
# Train Epoch: 21 [25600/60000 (43%)]	Loss: 0.000033
# Train Epoch: 21 [32000/60000 (53%)]	Loss: 0.002142
# Train Epoch: 21 [38400/60000 (64%)]	Loss: 0.000057
# Train Epoch: 21 [44800/60000 (75%)]	Loss: 0.000035
# Train Epoch: 21 [51200/60000 (85%)]	Loss: 0.000032
# Train Epoch: 21 [57600/60000 (96%)]	Loss: 0.023006
#
# Test set: Average loss: 0.0008, Accuracy: 59334/60000 (99%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 0.002315
# Train Epoch: 22 [6400/60000 (11%)]	Loss: 0.000161
# Train Epoch: 22 [12800/60000 (21%)]	Loss: 0.000523
# Train Epoch: 22 [19200/60000 (32%)]	Loss: 0.000011
# Train Epoch: 22 [25600/60000 (43%)]	Loss: 0.005975
# Train Epoch: 22 [32000/60000 (53%)]	Loss: 0.002223
# Train Epoch: 22 [38400/60000 (64%)]	Loss: 0.008781
# Train Epoch: 22 [44800/60000 (75%)]	Loss: 0.002388
# Train Epoch: 22 [51200/60000 (85%)]	Loss: 0.000233
# Train Epoch: 22 [57600/60000 (96%)]	Loss: 0.000662
#
# Test set: Average loss: 0.0009, Accuracy: 59335/60000 (99%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 0.000431
# Train Epoch: 23 [6400/60000 (11%)]	Loss: 0.026873
# Train Epoch: 23 [12800/60000 (21%)]	Loss: 0.000117
# Train Epoch: 23 [19200/60000 (32%)]	Loss: 0.001104
# Train Epoch: 23 [25600/60000 (43%)]	Loss: 0.001177
# Train Epoch: 23 [32000/60000 (53%)]	Loss: 0.000087
# Train Epoch: 23 [38400/60000 (64%)]	Loss: 0.000298
# Train Epoch: 23 [44800/60000 (75%)]	Loss: 0.036872
# Train Epoch: 23 [51200/60000 (85%)]	Loss: 0.000284
# Train Epoch: 23 [57600/60000 (96%)]	Loss: 0.000287
#
# Test set: Average loss: 0.0009, Accuracy: 59258/60000 (99%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 0.000096
# Train Epoch: 24 [6400/60000 (11%)]	Loss: 0.000020
# Train Epoch: 24 [12800/60000 (21%)]	Loss: 0.000006
# Train Epoch: 24 [19200/60000 (32%)]	Loss: 0.005317
# Train Epoch: 24 [25600/60000 (43%)]	Loss: 0.000158
# Train Epoch: 24 [32000/60000 (53%)]	Loss: 0.000310
# Train Epoch: 24 [38400/60000 (64%)]	Loss: 0.000755
# Train Epoch: 24 [44800/60000 (75%)]	Loss: 0.000173
# Train Epoch: 24 [51200/60000 (85%)]	Loss: 0.008366
# Train Epoch: 24 [57600/60000 (96%)]	Loss: 0.000122
#
# Test set: Average loss: 0.0009, Accuracy: 59334/60000 (99%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 0.025022
# Train Epoch: 25 [6400/60000 (11%)]	Loss: 0.014192
# Train Epoch: 25 [12800/60000 (21%)]	Loss: 0.000009
# Train Epoch: 25 [19200/60000 (32%)]	Loss: 0.000113
# Train Epoch: 25 [25600/60000 (43%)]	Loss: 0.000076
# Train Epoch: 25 [32000/60000 (53%)]	Loss: 0.024211
# Train Epoch: 25 [38400/60000 (64%)]	Loss: 0.000012
# Train Epoch: 25 [44800/60000 (75%)]	Loss: 0.000020
# Train Epoch: 25 [51200/60000 (85%)]	Loss: 0.008634
# Train Epoch: 25 [57600/60000 (96%)]	Loss: 0.002612
#
# Test set: Average loss: 0.0009, Accuracy: 59344/60000 (99%)
